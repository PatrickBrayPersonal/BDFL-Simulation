# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from IPython.display import Image
from src.API_Wrapper import API
from src.Reporter import Reporter
from src.Data_Generator import Data_Generator
from src.Simulator import Simulator
# Creds
LEAGUE_ID = '65522'
USER_AGENT = 'brayps_user_agent'
# Current week of the season
week = 1
# Number of seasons to run
n = 1000
# Instatiate Classes
api = API(leagueid=LEAGUE_ID, user_agent=USER_AGENT)
rep = Reporter(api, week)
dg = Data_Generator(week, api, rep, n)
sim = Simulator(week, api, rep, dg, n)

# %% [markdown]
# # Babara Dodson's Fantasy League 2021 Simulation
# *version 1.0*
#
# *4 August 2021*
#
# Below is the results of 1000 simulations of the 2021 BDFL regular season. The methodology is far from perfect, but takes some cool things into account (like MPPP being boom or bust). You can read my report on it [here](https://nbviewer.jupyter.org/github/PatrickBrayPersonal/BDFL-Simulation/blob/main/src/Report.ipynb) or find the TLDR below.

# %% [markdown]
# ## Team Performance

# %%
pd.options.display.float_format = '{:,.2f}'.format
sim.team_df.sort_values('mean_ppg', ascending=False)
# Out:
#                               total_wins  average_wins  total_pts  mean_ppg  \
# team
# The Youth Academy                  10496         10.50 764,404.53    117.54
# D.K. Mudbone                        9210          9.21 710,859.46    109.30
# Folk the King                       6967          6.97 668,956.94    102.22
# Jeff Janis Fan Club                 7564          7.56 645,958.35     99.39
# Half Chubb                          7497          7.50 639,678.18     98.03
# Suck My Ditka                       6638          6.64 609,406.89     93.77
# Do Your Job                         6294          6.29 600,355.46     92.76
# you know why i'm here               6305          6.30 583,372.89     89.50
# Rodger Goodella                     6055          6.05 577,821.48     88.99
# Free hernandez                      4978          4.98 561,084.86     86.64
# WhatDaTruck                         3502          3.50 489,982.28     75.45
# Marcus Peters' Peter Peckers        2494          2.49 435,316.64     66.95
#
#                               std_ppg  max_game  min_game
# team
# The Youth Academy               28.21    244.89      5.96
# D.K. Mudbone                    29.83    230.23     -2.36
# Folk the King                   30.08    214.65    -11.60
# Jeff Janis Fan Club             30.39    212.81    -39.91
# Half Chubb                      27.41    196.00      1.59
# Suck My Ditka                   27.57    197.79      4.70
# Do Your Job                     28.10    193.37    -23.92
# you know why i'm here           29.30    194.71    -14.66
# Rodger Goodella                 29.99    206.79    -24.11
# Free hernandez                  29.33    200.03    -16.00
# WhatDaTruck                     26.05    172.91    -21.63
# Marcus Peters' Peter Peckers    24.76    152.88    -24.13

# %% [markdown]
# ## Playoff Chances

# %%
sim.outcome_df.sort_values('made_playoffs', ascending=False)
# Out:
#                               made_playoffs  average_league_finish
# id
# The Youth Academy                      1.00                   1.48
# D.K. Mudbone                           0.96                   2.61
# Half Chubb                             0.80                   4.96
# Jeff Janis Fan Club                    0.68                   4.89
# Folk the King                          0.62                   5.38
# Do Your Job                            0.51                   6.89
# you know why i'm here                  0.47                   7.07
# Suck My Ditka                          0.42                   6.32
# Rodger Goodella                        0.34                   7.39
# Free hernandez                         0.18                   8.86
# WhatDaTruck                            0.01                  10.59
# Marcus Peters' Peter Peckers           0.00                  11.53

# %%
# dg.score_df.loc[dg.score_df.name_player == 'Matthew Stafford']
# dg.score_df.name_player.unique()
roster_df = dg.score_df
roster_df.loc[roster_df.name_player == 'Ezekiel Elliott']
# Out:
#      id_franchise player_status player_id position      name_player id_player  \
# 5292         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5293         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5294         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5295         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5296         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5297         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5298         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5299         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5300         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5301         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5302         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5303         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5304         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5305         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5306         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5307         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5308         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
# 5309         0008        ROSTER     12625       RB  Ezekiel Elliott     12625
#
#      team name_franchise  week  opp  weeks_remaining norm_name_player  \
# 5292  DAL  Folk the King     1  TBB               18   ezekielelliott
# 5293  DAL  Folk the King     2  LAC               18   ezekielelliott
# 5294  DAL  Folk the King     3  PHI               18   ezekielelliott
# 5295  DAL  Folk the King     4  CAR               18   ezekielelliott
# 5296  DAL  Folk the King     5  NYG               18   ezekielelliott
# 5297  DAL  Folk the King     6  NEP               18   ezekielelliott
# 5298  DAL  Folk the King     7  BYE               18   ezekielelliott
# 5299  DAL  Folk the King     8  MIN               18   ezekielelliott
# 5300  DAL  Folk the King     9  DEN               18   ezekielelliott
# 5301  DAL  Folk the King    10  ATL               18   ezekielelliott
# 5302  DAL  Folk the King    11  KCC               18   ezekielelliott
# 5303  DAL  Folk the King    12  LVR               18   ezekielelliott
# 5304  DAL  Folk the King    13  NOS               18   ezekielelliott
# 5305  DAL  Folk the King    14  WAS               18   ezekielelliott
# 5306  DAL  Folk the King    15  NYG               18   ezekielelliott
# 5307  DAL  Folk the King    16  WAS               18   ezekielelliott
# 5308  DAL  Folk the King    17  ARI               18   ezekielelliott
# 5309  DAL  Folk the King    18  PHI               18   ezekielelliott
#
#       mean_pts pos_rank  fran_pos_rank  start  flex_rank  \
# 5292      9.26      RB1              2   True        NaN
# 5293     11.76      RB1              1   True        NaN
# 5294     11.17      RB1              1   True        NaN
# 5295     12.22      RB1              2   True        NaN
# 5296     12.41      RB1              2   True        NaN
# 5297     12.55      RB1              2   True        NaN
# 5298      0.00      RB1              7  False      16.00
# 5299     14.25      RB1              1   True        NaN
# 5300     12.61      RB1              1   True        NaN
# 5301      9.92      RB1              1   True        NaN
# 5302     13.01      RB1              2   True        NaN
# 5303     15.30      RB1              1   True        NaN
# 5304      9.20      RB1              2   True        NaN
# 5305      9.85      RB1              2   True        NaN
# 5306     12.41      RB1              1   True        NaN
# 5307      9.85      RB1              2   True        NaN
# 5308     12.35      RB1              2   True        NaN
# 5309     11.17      RB1              1   True        NaN
#
#                                                     pts
# 5292  [3.6084295307240573, 2.736566556215397, 4.0984...
# 5293  [9.441083418370436, 11.069144587285539, 10.324...
# 5294  [6.993866015722951, 12.509327320644967, 10.233...
# 5295  [2.7312764985564755, 0.5834205568969191, -0.75...
# 5296  [10.176798067114445, 5.12213676232906, 2.66024...
# 5297  [9.461245347696721, 7.622089055022801, 9.08467...
# 5298
# 5299  [14.070200204376587, 11.600885791951018, 8.896...
# 5300  [5.607417279749564, 4.989498599407364, 4.47270...
# 5301  [7.685925194848746, 5.090981351284766, 1.99300...
# 5302  [7.4776985324280565, 9.060498232544859, 10.028...
# 5303  [7.749939687690905, 11.640840727231954, 9.8199...
# 5304  [7.601949539051965, 6.020967477148072, 7.60170...
# 5305  [6.735184682722473, 6.634403586072688, 8.34281...
# 5306  [7.8752984056010185, 8.390264348790017, 8.1260...
# 5307  [4.5840637020644355, 7.64307063798695, 5.59211...
# 5308  [8.773787644099405, 7.370560981415148, 7.42957...
# 5309  [11.886250849897431, 7.603139993991448, 8.2474...

# %%
import pickle
picklefile = open('sim1_post_trade2', 'wb')
pickle.dump(sim, picklefile)

# %% [markdown]
# ## What Does This Mean?
# The simulation is based on projected player performance from fantasypros.com. These projections don't take into account injuries, breakout players, halftime-retirements, and all the unpredicable things that happen during a football season. The simulation only introduces randomness at the game-level which normalizes over 13 games. What this means is the simulation is a lot more confident than it should be and will predict a week 13 game with the same confidence as a week 1 game. For the playoff percentages, I would recommend imagining each team a little closer to 50% than where they are at now, and shrink that error each week we get closer to the playoffs.
#
# ## What Next?
# * Weekly Projections
#
#     * This methodology is a lot more effective once it can recieve weekly player projections. It could even help you set your lineup using more than just mean points. I'll let the groupme know when this is available.
#
# * Season-Level Player Distributions
#
#     * Some players have a chance at a breakout year. We'll incorporate a distribution on top of the fantasy pros projections to introduce the uncertainty you would expect from fantasy football at the season-level.
#
# * Player-Specific Variance / Non-Normal Distributions
#
#     * Right now the simulation treats the distribution of points from a player on a given week as normal (which is wrong and why you see negative game scores above), with a variance determined by the roster position. However, Will Fuller has a much larger variation in points than Cooper Kupp and we should capture that.
#
# * Simulate the Playoffs
